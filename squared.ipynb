# %%
pip install numpy matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
a = np.arange(1,100)
b = a**2
sns.lineplot(x=a,y=b).set(title="Example graph", xlabel="x", ylabel="$x^2$")
# Out:
# [Text(0.5, 1.0, 'Example graph'), Text(0.5, 0, 'x'), Text(0, 0.5, '$x^2$')]
